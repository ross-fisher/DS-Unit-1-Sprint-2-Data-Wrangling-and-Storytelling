# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanleeallred/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module4-sequence-your-narrative/LS_DS_124_Sequence_your_narrative_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Sequence Your Narrative - Assignment
#
# Today we will create a sequence of visualizations inspired by [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://www.youtube.com/watch?v=jbkSRLYSojo).
#
# Using this [data from Gapminder](https://github.com/open-numbers/ddf--gapminder--systema_globalis/):
# - [Income Per Person (GDP Per Capital, Inflation Adjusted) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv)
# - [Life Expectancy (in Years) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv)
# - [Population Totals, by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv)
# - [Entities](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv)
# - [Concepts](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv)

# %% [markdown]
# Objectives
# - sequence multiple visualizations
# - combine qualitative anecdotes with quantitative aggregates
#
# Links
# - [Hans Rosling’s TED talks](https://www.ted.com/speakers/hans_rosling)
# - [Spiralling global temperatures from 1850-2016](https://twitter.com/ed_hawkins/status/729753441459945474)
# - "[The Pudding](https://pudding.cool/) explains ideas debated in culture with visual essays."
# - [A Data Point Walks Into a Bar](https://lisacharlotterost.github.io/2016/12/27/datapoint-in-bar/): a thoughtful blog post about emotion and empathy in data storytelling

# %% [markdown]
# # ASSIGNMENT
#
#
# 1.   Replicate the Lesson Code
# 2.   Take it further by using the same gapminder dataset to create a sequence of visualizations that combined tell a story of your choosing.
#
# Get creative! Use text annotations to call out specific countries, maybe: change how the points are colored, change the opacity of the points, change their sized, pick a specific time window. Maybe only work with a subset of countries, change fonts, change background colors, etc. make it your own!

# %%
# TODO

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
income = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')
lifespan = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv')
population = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv')
entities = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv')
concepts = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv')

# %%
income.shape, lifespan.shape, population.shape, entities.shape, concepts.shape
# Out:
# ((46513, 3), (44370, 3), (59297, 3), (273, 33), (590, 16))

# %%
income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
lifespan.head()
# Out:
#    geo  time  life_expectancy_years
# 0  abw  1800                  34.42
# 1  abw  1801                  34.42
# 2  abw  1802                  34.42
# 3  abw  1803                  34.42
# 4  abw  1804                  34.42

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
pd.options.display.max_columns=500
entities.head()
# Out:
#   country alt_5                    alternative_1 alternative_2 alternative_3  \
# 0    abkh   NaN                              NaN           NaN           NaN
# 1     abw   NaN                              NaN           NaN           NaN
# 2     afg   NaN  Islamic Republic of Afghanistan           NaN           NaN
# 3     ago   NaN                              NaN           NaN           NaN
# 4     aia   NaN                              NaN           NaN           NaN
#
#   alternative_4_cdiac arb1 arb2 arb3 arb4 arb5 arb6 g77_and_oecd_countries  \
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 1               Aruba  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 2         Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 3              Angola  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
#
# ...

# %%
#concepts.head()

# %%
print(income.shape)
print(lifespan.shape)
# Out:
# (46513, 3)
# (44370, 3)

# %%
# inner join, merges only on rows where 
# the same columns match in values
df = pd.merge(income, lifespan)
print(df.shape)
df = pd.merge(income, lifespan, on=['geo','time'], how='inner')
print(df.shape)

df.head()
# Out:
# (40437, 4)
# (40437, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
# population : geo,time,population_total
df = pd.merge(df, population) 
print(df.shape)
df.head()
# Out:
# (40437, 5)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years  population_total
# 0                  28.21           3280000
# 1                  28.20           3280000
# 2                  28.19           3280000
# 3                  28.18           3280000
# 4                  28.17           3280000

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
entities['world_6region'].value_counts()
# Out:
# europe_central_asia         77
# sub_saharan_africa          53
# america                     53
# east_asia_pacific           46
# middle_east_north_africa    23
# south_asia                   8
# Name: world_6region, dtype: int64

# %%
entities['world_4region'].value_counts()
# Out:
# asia        80
# europe      73
# africa      61
# americas    57
# Name: world_4region, dtype: int64

# %%
columns = ['country', 'name', 'world_4region', 'world_6region']
subset = entities[columns]
subset.head()
# Out:
#   country         name world_4region        world_6region
# 0    abkh     Abkhazia        europe  europe_central_asia
# 1     abw        Aruba      americas              america
# 2     afg  Afghanistan          asia           south_asia
# 3     ago       Angola        africa   sub_saharan_africa
# 4     aia     Anguilla      americas              america

# %%
merged = pd.merge(df, subset, left_on='geo', right_on='country')
merged.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years  population_total country         name world_4region  \
# 0                  28.21           3280000     afg  Afghanistan          asia
# 1                  28.20           3280000     afg  Afghanistan          asia
# 2                  28.19           3280000     afg  Afghanistan          asia
# 3                  28.18           3280000     afg  Afghanistan          asia
# 4                  28.17           3280000     afg  Afghanistan          asia
#
#   world_6region
# 0    south_asia
# 1    south_asia
# 2    south_asia
# 3    south_asia
# 4    south_asia

# %%
merged = merged.drop('geo', axis='columns')
merged.head()
# Out:
#    time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  1800                                                603
# 1  1801                                                603
# 2  1802                                                603
# 3  1803                                                603
# 4  1804                                                603
#
#    life_expectancy_years  population_total country         name world_4region  \
# 0                  28.21           3280000     afg  Afghanistan          asia
# 1                  28.20           3280000     afg  Afghanistan          asia
# 2                  28.19           3280000     afg  Afghanistan          asia
# 3                  28.18           3280000     afg  Afghanistan          asia
# 4                  28.17           3280000     afg  Afghanistan          asia
#
#   world_6region
# 0    south_asia
# 1    south_asia
# 2    south_asia
# 3    south_asia
# 4    south_asia

# %%
merged = merged.rename(columns = {
    'country': 'country_code',
    'time': 'year', 
    'income_per_person_gdppercapita_ppp_inflation_adjusted': 'income', 
    'life_expectancy_years': 'lifespan',
    'population_total': 'population',
    'name': 'country',
    'world_6region': '6region',
    'world_4region': '4region'
})

merged.head()
# Out:
#    year  income  lifespan  population country_code      country 4region  \
# 0  1800     603     28.21     3280000          afg  Afghanistan    asia
# 1  1801     603     28.20     3280000          afg  Afghanistan    asia
# 2  1802     603     28.19     3280000          afg  Afghanistan    asia
# 3  1803     603     28.18     3280000          afg  Afghanistan    asia
# 4  1804     603     28.17     3280000          afg  Afghanistan    asia
#
#       6region
# 0  south_asia
# 1  south_asia
# 2  south_asia
# 3  south_asia
# 4  south_asia

# %%
merged.dtypes
# Out:
# year              int64
# income            int64
# lifespan        float64
# population        int64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
merged.describe(exclude='number')
# Out:
#        country_code     country 4region              6region
# count         40437       40437   40437                40437
# unique          187         187       4                    6
# top             bwa  Luxembourg  africa  europe_central_asia
# freq            219         219   11826                10778

# %%
merged.country.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Brunei',
#        'Bhutan', 'Botswana', 'Central African Republic', 'Canada',
#        'Switzerland', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic',
#        'Algeria', 'Ecuador', 'Egypt', 'Eritrea', 'Spain', 'Estonia',
#        'Ethiopia', 'Finland', 'Fiji', 'France', 'Micronesia, Fed. Sts.',
#        'Gabon', 'United Kingdom', 'Georgia', 'Ghana', 'Guinea', 'Gambia',
# ...

# %%
usa = merged[merged.country == 'United States']
usa.head()
# Out:
#        year  income  lifespan  population country_code        country  \
# 38028  1800    2127     39.41     6801854          usa  United States
# 38029  1801    2167     39.41     6933517          usa  United States
# 38030  1802    2202     39.41     7067728          usa  United States
# 38031  1803    2166     39.41     7204538          usa  United States
# 38032  1804    2165     39.41     7343995          usa  United States
#
#         4region  6region
# 38028  americas  america
# 38029  americas  america
# 38030  americas  america
# 38031  americas  america
# 38032  americas  america

# %%
usa[usa.year.isin([1818, 1918, 2018])]
# Out:
#        year  income  lifespan  population country_code        country  \
# 38046  1818    2258     39.41     9879049          usa  United States
# 38146  1918    9371     47.18   106721812          usa  United States
# 38246  2018   54898     79.14   326766748          usa  United States
#
#         4region  6region
# 38046  americas  america
# 38146  americas  america
# 38246  americas  america

# %%
china = merged[merged.country=='China']
china[china.year.isin([1818,1918,2018])]
# Out:
#       year  income  lifespan  population country_code country 4region  \
# 6854  1818     985     32.00   374161494          chn   China    asia
# 6954  1918     989     22.13   462444535          chn   China    asia
# 7054  2018   16018     76.92  1415045928          chn   China    asia
#
#                 6region
# 6854  east_asia_pacific
# 6954  east_asia_pacific
# 7054  east_asia_pacific

# %%
import seaborn as sns
from dfply import *
now = merged >> mask(X.year == 2018)
now.head()
# Out:
#       year  income  lifespan  population country_code               country  \
# 218   2018    1867     58.69    36373176          afg           Afghanistan
# 437   2018    5846     65.19    30774205          ago                Angola
# 656   2018   12424     78.01     2934363          alb               Albania
# 922   2018   68231     76.89     9541615          are  United Arab Emirates
# 1141  2018   18942     76.97    44688864          arg             Argentina
#
#        4region                   6region
# 218       asia                south_asia
# 437     africa        sub_saharan_africa
# 656     europe       europe_central_asia
# 922       asia  middle_east_north_africa
# 1141  americas                   america

# %%
sns.relplot(x='income', y='lifespan', hue='6region',
            size='population', sizes=(50,400), data=now)

plt.xscale('log')
plt.ylim(20, 85)
# Out:
# (20, 85)

# %%
# sorting
(now >> arrange(X.income, ascending=False)).head()
# Out:
#        year  income  lifespan  population country_code     country 4region  \
# 30362  2018  121033     80.71     2694849          qat       Qatar    asia
# 22212  2018   99034     82.39      590321          lux  Luxembourg  europe
# 31895  2018   83888     84.03     5791901          sgp   Singapore    asia
# 5521   2018   76943     77.36      434076          brn      Brunei    asia
# 20241  2018   68359     79.96     4197128          kwt      Kuwait    asia
#
#                         6region
# 30362  middle_east_north_africa
# 22212       europe_central_asia
# 31895         east_asia_pacific
# 5521          east_asia_pacific
# 20241  middle_east_north_africa

# %%
now_qatar = now >> mask(X.country == 'Qatar')
now_qatar >> head()
# Out:
#        year  income  lifespan  population country_code country 4region  \
# 30362  2018  121033     80.71     2694849          qat   Qatar    asia
#
#                         6region
# 30362  middle_east_north_africa

# %%
sns.relplot(x='income', y='lifespan', hue='6region',
            size='population', sizes=(50, 400), data=now)
plt.xscale('log')
plt.ylim(20,85)
plt.title('The world in 2018')
plt.text(x=now_qatar.income-5000, y=now_qatar.lifespan+1,s='Qatar')
plt.show()

# %%
years = [1818, 1918, 2018]
centuries = merged >> mask(X.year.isin(years))
fig = sns.relplot(x='income', y='lifespan', hue='6region', size='population',
                  sizes=(50,400), col='year', data=centuries)

plt.xscale('log')
plt.text(x=now_qatar.income-5000, y=now_qatar.lifespan+1,s='Qatar')

# Set titles
axes = fig.axes.flatten()
[ax.set_title(year) for ax,year in zip(axes,years)]
# Out:
# [Text(0.5, 1, '1818'), Text(0.5, 1, '1918'), Text(0.5, 1, '2018')]

# %%
years = [1918, 1938, 1978, 1998, 2018]

decades = merged >> mask(X.year.isin(years))

# %%
sns.relplot(x='income',y='lifespan',hue='6region',size='population',
            col='year', data=decades)
plt.show()

# %%
import datetime
for year in years:
    sns.relplot(x='income', y='lifespan',hue='6region',size='population',
                data=merged[merged.year==year])
    plt.xscale('log')
    plt.xlim((150,150000))
    plt.ylim((0,90))
    plt.title(year)
    plt.axvline(x=1400,color='grey')
    plt.axhline(y=40,color='grey')

# %%
merged['year'].head()
# Out:
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# Name: year, dtype: int64

# %%
merged.dtypes
# Out:
# year              int64
# income            int64
# lifespan        float64
# population        int64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

colormap = {'south_asia' : 'blue',
            'sub_saharan_africa':'orange',
            'europe_central_asia':'green',
            'middle_east_north_africa':'maroon',
            'america':'cyan',
            'east_asia_pacific':'brown'
           }


patches = [mpatches.Patch(color=c,label=l) for l,c in zip(colormap.keys(),colormap.values())]
end_game = merged[merged.year==2018][merged.lifespan < 60]

for i,year in enumerate(years):
    df = merged[merged.year == year]
    fig = plt.figure(figsize=(10,5))
    if i == 0: 
        plt.suptitle('Countries with lifespan < 60',x=.2,y=1.15,fontsize=20,fontweight='bold')
    # [left bottom width height]
    ax  = fig.add_axes([0.0, 0.0, 0.66, 1.0])
    ax.set_title(year)
    ax.set_xlim(0,90)
    ax.set_xlabel('Lifespan')
    ax.set_ylabel('Income')
    plt.style.use("fivethirtyeight")
    sub = df[df.lifespan < 60]
    colorlist = sub['6region'].apply(lambda x: colormap[x])
    ax.scatter(sub.lifespan,sub.income,color=colorlist)
    
    
    plt.legend(handles=patches, loc='upper left',fontsize=10)

# plot the names of every country left at the end
end_guys = pd.merge(end_game, sub)
for country in end_guys.country:
    sub = merged[merged.year==2018][merged.lifespan<60][merged.country == country].iloc[0]
    ax.text(x=sub.lifespan, y=sub.income,s=sub.country)
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
year_df.population

# %%
# ?_bin

# %%
for l,r in money_bins:
    money_slice = merged[l < merged.income < r]
    sns.relplot(x='income', y='lifespan', hue='6region',
            size='population', sizes=(50, 400), data=money_slice)

# %%
merged.income

# %% [markdown]
# # STRETCH OPTIONS
#
# ## 1. Animate!
#
# - [How to Create Animated Graphs in Python](https://towardsdatascience.com/how-to-create-animated-graphs-in-python-bb619cc2dec1)
# - Try using [Plotly](https://plot.ly/python/animations/)!
# - [The Ultimate Day of Chicago Bikeshare](https://chrisluedtke.github.io/divvy-data.html) (Lambda School Data Science student)
# - [Using Phoebe for animations in Google Colab](https://colab.research.google.com/github/phoebe-project/phoebe2-docs/blob/2.1/tutorials/animations.ipynb)
#
# ## 2. Study for the Sprint Challenge
#
# - Concatenate DataFrames
# - Merge DataFrames
# - Reshape data with `pivot_table()` and `.melt()`
# - Be able to reproduce a FiveThirtyEight graph using Matplotlib or Seaborn.
#
# ## 3. Work on anything related to your portfolio site / Data Storytelling Project

# %%
# TODO
